# %%
# importing basic libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Data Gathering

# %%
deliveries=pd.read_csv(r"C:\Users\pooja\OneDrive\Desktop\ipl-rough\deliveries.csv")
deliveries.sample(7)
# Out:
#         match_id  inning                 batting_team  \
# 203673   1254100       1             Rajasthan Royals
# 124137    980915       1          Sunrisers Hyderabad
# 57525     501267       2               Mumbai Indians
# 127521    980943       1          Sunrisers Hyderabad
# 216768   1304083       1         Lucknow Super Giants
# 183985   1216512       1        Kolkata Knight Riders
# 225532   1312199       1  Royal Challengers Bangalore
#
#                    bowling_team  over  ball        batter          bowler  \
# 203673      Sunrisers Hyderabad     2     4   YBK Jaiswal  Sandeep Sharma
# 124137    Kolkata Knight Riders     7     3      DJ Hooda      AD Russell
# 57525     Kolkata Knight Riders     5     1  SR Tendulkar        L Balaji
# 127521  Rising Pune Supergiants    10     6      S Dhawan        R Bhatia
# 216768           Mumbai Indians     7     6      KL Rahul      HR Shokeen
# 183985      Sunrisers Hyderabad    15     6    KD Karthik  Sandeep Sharma
# 225532         Rajasthan Royals     7     6  F du Plessis        R Ashwin
#
#             non_striker  batsman_runs  extra_runs  total_runs extras_type  \
# 203673        SV Samson             0           0           0         NaN
# 124137       EJG Morgan             0           0           0         NaN
# 57525   Harbhajan Singh             1           0           1         NaN
# 127521          NV Ojha             1           0           1         NaN
# 216768        MK Pandey             1           0           1         NaN
# 183985       EJG Morgan             1           0           1         NaN
# 225532       RM Patidar             0           0           0         NaN
#
#         is_wicket player_dismissed dismissal_kind fielder
# 203673          0              NaN            NaN     NaN
# 124137          0              NaN            NaN     NaN
# 57525           0              NaN            NaN     NaN
# 127521          0              NaN            NaN     NaN
# 216768          0              NaN            NaN     NaN
# 183985          0              NaN            NaN     NaN
# 225532          0              NaN            NaN     NaN

# %%
matches=pd.read_csv(r"C:\Users\pooja\OneDrive\Desktop\ipl-rough\matches.csv")
matches.sample(7)
# Out:
#            id   season       city        date match_type player_of_match  \
# 2      335984  2007/08      Delhi  2008-04-19     League     MF Maharoof
# 889   1304060     2022       Pune  2022-04-06     League      PJ Cummins
# 235    501259     2011     Mumbai  2011-05-16     League        A Mishra
# 550    980967     2016  Hyderabad  2016-05-06     League         B Kumar
# 1065  1426280     2024    Kolkata  2024-04-26     League     JM Bairstow
# 744   1178424     2019  Bengaluru  2019-04-30     League             NaN
# 745   1178425     2019    Chennai  2019-05-01     League        MS Dhoni
#
#                                               venue  \
# 2                                  Feroz Shah Kotla
# 889   Maharashtra Cricket Association Stadium, Pune
# 235                      Dr DY Patil Sports Academy
# 550       Rajiv Gandhi International Stadium, Uppal
# 1065                          Eden Gardens, Kolkata
# 744                           M.Chinnaswamy Stadium
# 745                          MA Chidambaram Stadium
#
#                             team1                  team2  \
# 2                Delhi Daredevils       Rajasthan Royals
# 889                Mumbai Indians  Kolkata Knight Riders
# 235                 Pune Warriors        Deccan Chargers
# 550           Sunrisers Hyderabad          Gujarat Lions
# 1065        Kolkata Knight Riders           Punjab Kings
# 744   Royal Challengers Bangalore       Rajasthan Royals
# 745           Chennai Super Kings         Delhi Capitals
#
#                 toss_winner toss_decision                 winner     result  \
# 2          Rajasthan Royals           bat       Delhi Daredevils    wickets
# 889   Kolkata Knight Riders         field  Kolkata Knight Riders    wickets
# 235         Deccan Chargers         field        Deccan Chargers    wickets
# 550     Sunrisers Hyderabad         field    Sunrisers Hyderabad    wickets
# 1065           Punjab Kings         field           Punjab Kings    wickets
# 744        Rajasthan Royals         field                    NaN  no result
# 745          Delhi Capitals         field    Chennai Super Kings       runs
#
#       result_margin  target_runs  target_overs super_over method  \
# 2               9.0        130.0          20.0          N    NaN
# 889             5.0        162.0          20.0          N    NaN
# 235             6.0        137.0          20.0          N    NaN
# 550             5.0        127.0          20.0          N    NaN
# 1065            8.0        262.0          20.0          N    NaN
# 744             NaN         63.0           5.0          N    NaN
# 745            80.0        180.0          20.0          N    NaN
#
#            umpire1                umpire2
# 2        Aleem Dar         GA Pratapkumar
# 889   BNJ Oxenford  KN Ananthapadmanabhan
# 235         S Ravi            SK Tarapore
# 550      M Erasmus                 S Ravi
# 1065  AK Chaudhary               YC Barde
# 744       NJ Llong              UV Gandhe
# 745    AY Dandekar            Nitin Menon

# %% [markdown]
# ### Data Cleaning

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %%
deliveries['batting_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Royal Challengers Bangalore',
#        'Chennai Super Kings', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Mumbai Indians', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %% [markdown]
# 1. due to change in names of teams their are many teams so will convert into 8 teams.
# 2. as we are creating predictor we will consider only present 8 teams.

# %%
def change_name(team_name):
    if team_name in ['Rising Pune Supergiants','Pune Warriors']:
        return 'Rising Pune Supergiant'
    elif team_name=='Royal Challengers Bengaluru':
        return 'Royal Challengers Bangalore'
    elif team_name=='Deccan Chargers':
        return 'Sunrisers Hyderabad'
    elif team_name == 'Delhi Daredevils':
        return 'Delhi Capitals'
    elif team_name== 'Gujarat Lions':
        return 'Gujarat Titans'
    elif team_name == 'Kings XI Punjab':
        return 'Punjab Kings'
    else:
        return team_name

# %%
deliveries['batting_team']=deliveries['batting_team'].apply(change_name)
deliveries['bowling_team']=deliveries['bowling_team'].apply(change_name)
matches['team1']=matches['team1'].apply(change_name)
matches['team2']=matches['team2'].apply(change_name)

# %%
deliveries=deliveries[(deliveries['batting_team']!='Kochi Tuskers Kerala')&(deliveries['bowling_team']!='Kochi Tuskers Kerala')]
deliveries=deliveries[(deliveries['batting_team']!='Rising Pune Supergiant')&(deliveries['bowling_team']!='Rising Pune Supergiant')]
matches=matches[(matches['team1']!='Kochi Tuskers Kerala')&(matches['team2']!='Kochi Tuskers Kerala')]
matches=matches[(matches['team1']!='Rising Pune Supergiant')&(matches['team2']!='Rising Pune Supergiant')]

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240047 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          240047 non-null  int64
#  1   inning            240047 non-null  int64
#  2   batting_team      240047 non-null  object
#  3   bowling_team      240047 non-null  object
#  4   over              240047 non-null  int64
#  5   ball              240047 non-null  int64
#  6   batter            240047 non-null  object
#  7   bowler            240047 non-null  object
#  8   non_striker       240047 non-null  object
#  9   batsman_runs      240047 non-null  int64
#  10  extra_runs        240047 non-null  int64
#  11  total_runs        240047 non-null  int64
#  12  extras_type       13091 non-null   object
#  13  is_wicket         240047 non-null  int64
#  14  player_dismissed  11921 non-null   object
#  15  dismissal_kind    11921 non-null   object
#  16  fielder           8628 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.0+ MB

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1006 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1006 non-null   int64
#  1   season           1006 non-null   object
#  2   city             955 non-null    object
#  3   date             1006 non-null   object
#  4   match_type       1006 non-null   object
#  5   player_of_match  1002 non-null   object
#  6   venue            1006 non-null   object
#  7   team1            1006 non-null   object
#  8   team2            1006 non-null   object
#  9   toss_winner      1006 non-null   object
#  10  toss_decision    1006 non-null   object
#  11  winner           1002 non-null   object
#  12  result           1006 non-null   object
#  13  result_margin    988 non-null    float64
#  14  target_runs      1004 non-null   float64
#  15  target_overs     1004 non-null   float64
#  16  super_over       1006 non-null   object
#  17  method           17 non-null     object
#  18  umpire1          1006 non-null   object
#  19  umpire2          1006 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 165.0+ KB

# %% [markdown]
# ## runs left

# %%
total_runs_df=deliveries.groupby(['match_id','inning'])['total_runs'].sum().reset_index()
total_runs_df
# Out:
#       match_id  inning  total_runs
# 0       335982       1         222
# 1       335982       2          82
# 2       335983       1         240
# 3       335983       2         207
# 4       335984       1         129
# ...        ...     ...         ...
# 2035   1426310       2         174
# 2036   1426311       1         175
# 2037   1426311       2         139
# 2038   1426312       1         113
# 2039   1426312       2         114
#
# [2040 rows x 3 columns]

# %%
total_runs_df=total_runs_df[total_runs_df['inning']==1]

# %%
matches_df=matches.merge(total_runs_df[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
matches_df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'total_runs'],
#       dtype='object')

# %%
matches_df=matches_df[['match_id','city','winner','total_runs']]

# %%
delivery_df=matches_df.merge(deliveries,on='match_id')

# %%
delivery_df=delivery_df[delivery_df['inning']==2]

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 240042   1426312    Chennai  Kolkata Knight Riders           113       2
# 240043   1426312    Chennai  Kolkata Knight Riders           113       2
# 240044   1426312    Chennai  Kolkata Knight Riders           113       2
# 240045   1426312    Chennai  Kolkata Knight Riders           113       2
# 240046   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 240042        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 240043        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 240044        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 240045        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 240046        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter         bowler non_striker  batsman_runs  extra_runs  \
# 124     R Dravid       AB Dinda    W Jaffer             1           0
# 125     W Jaffer       AB Dinda    R Dravid             0           1
# 126     W Jaffer       AB Dinda    R Dravid             0           0
# 127     W Jaffer       AB Dinda    R Dravid             1           0
# 128     R Dravid       AB Dinda    W Jaffer             1           0
# ...          ...            ...         ...           ...         ...
# 240042   SS Iyer     AK Markram     VR Iyer             1           0
# 240043   VR Iyer     AK Markram     SS Iyer             1           0
# 240044   VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
# 240045   SS Iyer  Shahbaz Ahmed     VR Iyer             1           0
# 240046   VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
#
#         total_runs_y extras_type  is_wicket player_dismissed dismissal_kind  \
# 124                1         NaN          0              NaN            NaN
# 125                1       wides          0              NaN            NaN
# 126                0         NaN          0              NaN            NaN
# 127                1         NaN          0              NaN            NaN
# 128                1         NaN          0              NaN            NaN
# ...              ...         ...        ...              ...            ...
# 240042             1         NaN          0              NaN            NaN
# 240043             1         NaN          0              NaN            NaN
# 240044             1         NaN          0              NaN            NaN
# 240045             1         NaN          0              NaN            NaN
# 240046             1         NaN          0              NaN            NaN
#
#        fielder
# 124        NaN
# 125        NaN
# 126        NaN
# 127        NaN
# 128        NaN
# ...        ...
# 240042     NaN
# 240043     NaN
# 240044     NaN
# 240045     NaN
# 240046     NaN
#
# [115732 rows x 20 columns]

# %%
delivery_df['current_score']=delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']

# %%
delivery_df
# Out:
#         match_id       city                 winner  total_runs_x  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders           222       2
# 125       335982  Bangalore  Kolkata Knight Riders           222       2
# 126       335982  Bangalore  Kolkata Knight Riders           222       2
# 127       335982  Bangalore  Kolkata Knight Riders           222       2
# 128       335982  Bangalore  Kolkata Knight Riders           222       2
# ...          ...        ...                    ...           ...     ...
# 240042   1426312    Chennai  Kolkata Knight Riders           113       2
# 240043   1426312    Chennai  Kolkata Knight Riders           113       2
# 240044   1426312    Chennai  Kolkata Knight Riders           113       2
# 240045   1426312    Chennai  Kolkata Knight Riders           113       2
# 240046   1426312    Chennai  Kolkata Knight Riders           113       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 240042        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 240043        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 240044        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 240045        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 240046        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter  ... batsman_runs extra_runs  total_runs_y  extras_type  \
# 124     R Dravid  ...            1          0             1          NaN
# 125     W Jaffer  ...            0          1             1        wides
# 126     W Jaffer  ...            0          0             0          NaN
# 127     W Jaffer  ...            1          0             1          NaN
# 128     R Dravid  ...            1          0             1          NaN
# ...          ...  ...          ...        ...           ...          ...
# 240042   SS Iyer  ...            1          0             1          NaN
# 240043   VR Iyer  ...            1          0             1          NaN
# 240044   VR Iyer  ...            1          0             1          NaN
# 240045   SS Iyer  ...            1          0             1          NaN
# 240046   VR Iyer  ...            1          0             1          NaN
#
#         is_wicket player_dismissed  dismissal_kind fielder current_score  \
# 124             0              NaN             NaN     NaN             1
# 125             0              NaN             NaN     NaN             2
# 126             0              NaN             NaN     NaN             2
# 127             0              NaN             NaN     NaN             3
# 128             0              NaN             NaN     NaN             4
# ...           ...              ...             ...     ...           ...
# 240042          0              NaN             NaN     NaN           110
# 240043          0              NaN             NaN     NaN           111
# 240044          0              NaN             NaN     NaN           112
# 240045          0              NaN             NaN     NaN           113
# 240046          0              NaN             NaN     NaN           114
#
#        runs_left
# 124          221
# 125          220
# 126          220
# 127          219
# 128          218
# ...          ...
# 240042         3
# 240043         2
# 240044         1
# 240045         0
# 240046        -1
#
# [115732 rows x 22 columns]

# %%
delivery_df['ball_left']=120 - (delivery_df['over']*6 + delivery_df['ball'])
# Out:
# 124       119
# 125       118
# 126       117
# 127       116
# 128       115
#          ...
# 240042     61
# 240043     60
# 240044     59
# 240045     58
# 240046     57
# Length: 115732, dtype: int64
